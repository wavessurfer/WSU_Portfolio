# %% [markdown]
# # Activity 3.2 – Recoding and Aggregating a Health Care Survey
#
# ## Part 1 – Three ways to recode
#
# Before we get the the main event, let’s practice recoding the survey
# data in three ways. In all cases, our goal is to assign a score of `5` to
# `"Strongly Agree"` down to a score of `1` to `"Strongly Disagree"`.
#
# | Old Label                    | Regular Coded Value |
# |------------------------------|---------------------|
# | `"Strongly Disagree"`          | 1                   |
# | `"Somewhat Disagree"`          | 2                   |
# | `"Neither Agree nor Disagree"` | 3                   |
# | `"Somewhat Agree"`             | 4                   |
# | `"Strongly Agree"`             | 5                   |
#
# **Preparation.** Recall that the `more_dfply.recode` function allows us to
# recode a column using a `dict`.

# %% [markdown]
# 1.  Load the health survey data found in the data folder.  Inspect the column names, then fix the issues with the `"."`s.  **Hint.** We can use `dfply.rename` with the `dict` unpacking trick.

# %%
import pandas as pd
pd.set_option("display.max_column",None)

# %%
health_survey = pd.read_csv("./data/health_survey.csv")
health_survey.sample(4)
# Out:
#       ID              F1                          F5              F2  \
# 195  196  Somewhat Agree  Neither Agree nor Disagree  Strongly Agree
# 42    43  Strongly Agree              Somewhat Agree  Strongly Agree
# 209  210  Somewhat Agree              Somewhat Agree  Strongly Agree
# 204  205  Strongly Agree              Somewhat Agree  Somewhat Agree
#
#                F1.1            F2.1                 F6              F4  \
# 195  Somewhat Agree  Strongly Agree  Strongly Disagree  Somewhat Agree
# 42   Strongly Agree  Strongly Agree  Somewhat Disagree  Strongly Agree
# 209  Somewhat Agree  Strongly Agree  Somewhat Disagree  Somewhat Agree
# 204  Strongly Agree  Strongly Agree     Somewhat Agree  Somewhat Agree
#
#                              F3               F5.1            F1.2  \
# 195              Somewhat Agree  Somewhat Disagree  Somewhat Agree
# 42   Neither Agree nor Disagree     Somewhat Agree  Strongly Agree
# 209              Somewhat Agree     Strongly Agree  Strongly Agree
# 204           Somewhat Disagree     Somewhat Agree  Strongly Agree
#
#                F2.2            F6.1                        F2.3  \
# 195  Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 42   Strongly Agree  Strongly Agree              Somewhat Agree
# 209  Strongly Agree  Somewhat Agree              Somewhat Agree
# 204  Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
#
#                            F4.1            F2.4               F5.2  \
# 195           Somewhat Disagree  Somewhat Agree  Somewhat Disagree
# 42   Neither Agree nor Disagree  Strongly Agree  Somewhat Disagree
# 209              Somewhat Agree  Somewhat Agree     Somewhat Agree
# 204           Somewhat Disagree  Somewhat Agree  Somewhat Disagree
#
#                F2.5            F6.2            F1.3            F2.6  \
# 195  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 42   Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 209  Strongly Agree  Strongly Agree  Somewhat Agree  Strongly Agree
# 204  Somewhat Agree  Strongly Agree  Strongly Agree  Somewhat Agree
#
#                            F5.3            F4.2            F2.7  \
# 195           Strongly Disagree  Somewhat Agree  Somewhat Agree
# 42               Somewhat Agree  Somewhat Agree  Strongly Agree
# 209  Neither Agree nor Disagree  Strongly Agree  Strongly Agree
# 204              Somewhat Agree  Somewhat Agree             NaN
#
#                   F3.1            F2.8                        F5.4  \
# 195     Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 42   Somewhat Disagree  Somewhat Agree              Somewhat Agree
# 209     Somewhat Agree  Somewhat Agree              Somewhat Agree
# 204     Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
#
#                   F3.2            F1.4               F3.3            F1.5  \
# 195     Somewhat Agree  Somewhat Agree     Somewhat Agree  Somewhat Agree
# 42   Somewhat Disagree  Somewhat Agree  Strongly Disagree  Strongly Agree
# 209     Somewhat Agree  Somewhat Agree     Somewhat Agree  Somewhat Agree
# 204  Somewhat Disagree  Somewhat Agree  Somewhat Disagree  Strongly Agree
#
#                   F5.5                        F6.3            F1.6  \
# 195  Strongly Disagree           Strongly Disagree  Strongly Agree
# 42   Strongly Disagree           Strongly Disagree  Strongly Agree
# 209  Somewhat Disagree  Neither Agree nor Disagree  Somewhat Agree
# 204  Strongly Disagree           Somewhat Disagree  Strongly Agree
#
#                   F5.6            F2.9                        F3.4  \
# 195  Somewhat Disagree  Somewhat Agree              Somewhat Agree
# 42   Somewhat Disagree  Somewhat Agree           Somewhat Disagree
# 209  Somewhat Disagree  Somewhat Agree              Somewhat Agree
# 204  Somewhat Disagree  Somewhat Agree  Neither Agree nor Disagree
#
#                   F4.3           F2.10               F1.7  \
# 195  Somewhat Disagree  Somewhat Agree     Somewhat Agree
# 42      Somewhat Agree  Strongly Agree  Somewhat Disagree
# 209  Somewhat Disagree  Somewhat Agree  Somewhat Disagree
# 204     Somewhat Agree  Somewhat Agree     Strongly Agree
#
#                            F6.4               F4.4            F5.7  \
# 195           Somewhat Disagree     Somewhat Agree  Somewhat Agree
# 42            Somewhat Disagree  Somewhat Disagree  Strongly Agree
# 209  Neither Agree nor Disagree     Strongly Agree  Somewhat Agree
# 204  Neither Agree nor Disagree     Somewhat Agree  Strongly Agree
#
#                            F3.5           F2.11
# 195           Somewhat Disagree  Somewhat Agree
# 42               Somewhat Agree  Somewhat Agree
# 209           Somewhat Disagree  Somewhat Agree
# 204  Neither Agree nor Disagree  Somewhat Agree

# %%
from dfply import *

# %%
health_survey_fixed = (health_survey
                      >> gather('question', "response", columns_from("F1"))
                      >> mutate(question = X.question.str.replace(".","_", regex=False))
                      >> spread("question","response")
                      )
health_survey_fixed.sample(5)
# Out:
#       ID              F1            F1_1            F1_2            F1_3  \
# 143  144  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 70    71  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 228  229  Somewhat Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 78    79  Strongly Agree  Strongly Agree  Somewhat Agree  Strongly Agree
# 184  185  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
#
#                F1_4            F1_5            F1_6            F1_7  \
# 143  Strongly Agree  Strongly Agree  Strongly Agree  Somewhat Agree
# 70   Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 228  Somewhat Agree  Strongly Agree  Strongly Agree  Somewhat Agree
# 78   Somewhat Agree  Somewhat Agree  Strongly Agree  Somewhat Agree
# 184  Somewhat Agree  Strongly Agree  Strongly Agree  Strongly Agree
#
#                  F2            F2_1           F2_10           F2_11  \
# 143  Somewhat Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 70   Strongly Agree  Strongly Agree  Somewhat Agree  Strongly Agree
# 228  Strongly Agree  Somewhat Agree  Somewhat Agree  Strongly Agree
# 78   Strongly Agree  Strongly Agree  Somewhat Agree  Somewhat Agree
# 184  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
#
#                F2_2            F2_3            F2_4            F2_5  \
# 143  Somewhat Agree  Somewhat Agree  Strongly Agree  Somewhat Agree
# 70   Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 228  Strongly Agree  Somewhat Agree  Strongly Agree  Strongly Agree
# 78   Somewhat Agree  Somewhat Agree  Somewhat Agree  Strongly Agree
# 184  Strongly Agree  Strongly Agree  Somewhat Agree  Strongly Agree
#
#                F2_6            F2_7            F2_8            F2_9  \
# 143  Strongly Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 70   Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 228  Strongly Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 78   Strongly Agree  Strongly Agree  Somewhat Agree  Strongly Agree
# 184  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
#
#                     F3               F3_1                        F3_2  \
# 143     Somewhat Agree     Strongly Agree              Somewhat Agree
# 70      Somewhat Agree     Somewhat Agree  Neither Agree nor Disagree
# 228     Somewhat Agree     Somewhat Agree              Somewhat Agree
# 78      Somewhat Agree  Somewhat Disagree           Somewhat Disagree
# 184  Somewhat Disagree  Somewhat Disagree           Strongly Disagree
#
#                   F3_3                        F3_4  \
# 143     Somewhat Agree  Neither Agree nor Disagree
# 70      Somewhat Agree              Somewhat Agree
# 228     Somewhat Agree              Somewhat Agree
# 78   Somewhat Disagree           Somewhat Disagree
# 184  Somewhat Disagree  Neither Agree nor Disagree
#
#                            F3_5              F4                        F4_1  \
# 143  Neither Agree nor Disagree  Somewhat Agree              Somewhat Agree
# 70   Neither Agree nor Disagree  Strongly Agree  Neither Agree nor Disagree
# 228              Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
# 78   Neither Agree nor Disagree  Somewhat Agree           Somewhat Disagree
# 184  Neither Agree nor Disagree  Strongly Agree           Strongly Disagree
#
#                F4_2                        F4_3            F4_4  \
# 143  Somewhat Agree              Somewhat Agree  Somewhat Agree
# 70   Strongly Agree  Neither Agree nor Disagree  Strongly Agree
# 228  Somewhat Agree  Neither Agree nor Disagree  Somewhat Agree
# 78   Strongly Agree           Somewhat Disagree  Somewhat Agree
# 184  Strongly Agree           Somewhat Disagree  Strongly Agree
#
#                     F5                        F5_1               F5_2  \
# 143  Somewhat Disagree              Somewhat Agree  Strongly Disagree
# 70   Somewhat Disagree              Strongly Agree  Strongly Disagree
# 228  Somewhat Disagree              Strongly Agree  Somewhat Disagree
# 78   Somewhat Disagree              Somewhat Agree  Somewhat Disagree
# 184     Strongly Agree  Neither Agree nor Disagree  Somewhat Disagree
#
#                   F5_3                        F5_4               F5_5  \
# 143     Somewhat Agree              Somewhat Agree  Somewhat Disagree
# 70      Somewhat Agree              Strongly Agree  Strongly Disagree
# 228     Somewhat Agree              Strongly Agree  Strongly Disagree
# 78      Somewhat Agree  Neither Agree nor Disagree  Somewhat Disagree
# 184  Somewhat Disagree  Neither Agree nor Disagree  Somewhat Disagree
#
#                            F5_6            F5_7                          F6  \
# 143           Somewhat Disagree  Somewhat Agree           Somewhat Disagree
# 70            Somewhat Disagree  Strongly Agree           Somewhat Disagree
# 228  Neither Agree nor Disagree  Strongly Agree              Somewhat Agree
# 78            Somewhat Disagree  Strongly Agree           Somewhat Disagree
# 184              Somewhat Agree  Strongly Agree  Neither Agree nor Disagree
#
#                F6_1            F6_2               F6_3  \
# 143  Strongly Agree  Strongly Agree  Somewhat Disagree
# 70   Strongly Agree  Strongly Agree  Somewhat Disagree
# 228  Strongly Agree  Somewhat Agree  Somewhat Disagree
# 78   Somewhat Agree  Strongly Agree  Somewhat Disagree
# 184  Strongly Agree  Strongly Agree  Somewhat Disagree
#
#                            F6_4
# 143              Somewhat Agree
# 70   Neither Agree nor Disagree
# 228           Somewhat Disagree
# 78               Somewhat Agree
# 184  Neither Agree nor Disagree

# %% [markdown]
# 2.  Use `unique` to verify the labels of various columns. Create a `dict` mapping each survey responses to the corresponding score.

# %%
health_survey_fixed.F1.unique()
# Out:
# array(['Somewhat Agree', 'Strongly Agree', 'Neither Agree nor Disagree',
#        'Somewhat Disagree'], dtype=object)

# %%
likert_map = {
    "Strongly Disagree" : 1,
    "Somewhat Disagree" : 2,
    "Neither Agree nor Disagree" : 3,
    "Somewhat Agree" : 4,
    "Strongly Agree" : 5
}

# %%
map1 = (health_survey_fixed
                            >> mutate(F2_num = X.F2.map(likert_map))
                            >> mutate(F2_num = X.F2_num.astype('Int64'))
                            >> select("F2", "F2_num"))
map1.sample(4)
# Out:
#                  F2  F2_num
# 208  Strongly Agree       5
# 203  Somewhat Agree       4
# 28   Somewhat Agree       4
# 32   Somewhat Agree       4

# %% [markdown]
# 3.  Test your dictionary with the `map` method on one of the columns.  The columns `F2` and `F1.1` are good test cases.

# %%
map1.F2_num.unique()
# Out:
# <IntegerArray>
# [4, 5, 3, 2, <NA>]
# Length: 5, dtype: Int64

# %% [markdown]
# 4. Explain why you should be using the `pandas` `Int64` data type here.  Details on the necessity and use of this data type can be found in [Lecture 2.4](https://github.com/wsu-stat489/module2_intro_to_pandas/blob/main/2_4_pandas_dtypes.ipynb)

# %% [markdown]
# <font color="blue"> *It deals better with missing values* </font>

# %% [markdown]
# #### Method 1 – Brute Force.
#
# The naïve approach to applying our mapping
# is the construct a `mutate`, writing one line per column. This will become
# annoying.

# %% [markdown]
# 1.  Create a pipe that uses `mutate` to transform at least 10 of the columns.

# %%
(health_survey_fixed
 >> mutate(F1_num = X.F1.map(likert_map).astype("Int64"))
 >> mutate(F1_1num = X.F1_1.map(likert_map).astype("Int64"))
 >> mutate(F1_2num = X.F1_2.map(likert_map).astype("Int64"))
 >> mutate(F1_3num = X.F1_3.map(likert_map).astype("Int64"))
 >> mutate(F1_4num = X.F1_4.map(likert_map).astype("Int64"))
 >> mutate(F1_5num = X.F1_5.map(likert_map).astype("Int64"))
 >> mutate(F1_6num = X.F1_6.map(likert_map).astype("Int64"))
 >> mutate(F1_7num = X.F1_7.map(likert_map).astype("Int64"))
 >> mutate(F2num = X.F2.map(likert_map).astype("Int64"))
 >> mutate(F2_1num = X.F2_1.map(likert_map).astype("Int64"))
 >> select(columns_to("F2_1"), columns_from("F1_num"))
 >> sample(4)
)
# Out:
#       ID                          F1                        F1_1  \
# 222  223              Strongly Agree              Strongly Agree
# 247  248  Neither Agree nor Disagree  Neither Agree nor Disagree
# 258  259              Somewhat Agree              Strongly Agree
# 219  220              Strongly Agree              Strongly Agree
#
#                F1_2            F1_3                        F1_4  \
# 222  Strongly Agree  Strongly Agree  Neither Agree nor Disagree
# 247  Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
# 258  Somewhat Agree  Somewhat Agree              Somewhat Agree
# 219  Somewhat Agree  Strongly Agree              Strongly Agree
#
#                            F1_5            F1_6                        F1_7  \
# 222              Somewhat Agree  Somewhat Agree              Somewhat Agree
# 247  Neither Agree nor Disagree  Somewhat Agree  Neither Agree nor Disagree
# 258              Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
# 219              Strongly Agree  Strongly Agree              Strongly Agree
#
#                  F2  F1_num  F1_1num  F1_2num  F1_3num  F1_4num  F1_5num  \
# 222  Somewhat Agree       5        5        5        5        3        4
# 247  Somewhat Agree       3        3        4        4        3        3
# 258  Strongly Agree       4        5        4        4        4        4
# 219  Somewhat Agree       5        5        4        5        5        5
#
#      F1_6num  F1_7num  F2num  F2_1num
# 222        4        4      4        5
# 247        4        3      4        4
# 258        4        3      5        5
# 219        5        5      4        5

# %% [markdown]
# 2.  Explain,
#
#     1.  in vivid detail, exactly how annoying it would be to continue
#         this process.

# %%
len(health_survey_fixed.columns)
# Out:
# 45

# %% [markdown]
# <font color="blue"> *There are 45 columns...* </font>

# %% [markdown]
#     B.  how this might be prone to buggy code.

# %% [markdown]
# <font color="blue"> *Too easy to mistype something and make errors, hard to read and understand code, difficult to spot mistakes* </font>

# %% [markdown]
# #### Method 2 – dictionary unpacking.
#
# Recall that we cleaned up repeated,
# similar transformations in [Lecture 3.5](https://github.com/wsu-stat489/module3_more_about_mutate/blob/main/3_5_DRY_and_many_transformations.ipynb). Let’s apply that approach here.
#
# 1.  Get a `list` of all the questions columns, e.g., using `dfply.columns_from`.

# %%
col_to_recode = columns_from('F1').evaluate(health_survey_fixed)
col_to_recode[0:4]
# Out:
# ['F1', 'F1_1', 'F1_2', 'F1_3']

# %% [markdown]
# 2.  Pick one of the columns and write the expression to transform that
#     column. Be sure to use the `df["col_string"]` method of referencing
#     the column.

# %%
health_survey_fixed["F1"].map(likert_map).astype("Int64").head()
# Out:
# 0    4
# 1    4
# 2    5
# 3    4
# 4    5
# Name: F1, dtype: Int64

# %% [markdown]
# 3.  Create a variable to hold this column string. Replace the hard coded
#     column name with a variable. Rerun to test.

# %%
c = "F1"
health_survey_fixed[c].map(likert_map).astype("Int64").head()
# Out:
# 0    4
# 1    4
# 2    5
# 3    4
# 4    5
# Name: F1, dtype: Int64

# %% [markdown]
# 4.  Convert the single expression to a `dict` using a comprehension
#     that iterates over all column names. We want the keys to the be the
#     column names and values the resulting recoded columns.  Rerun to
#     test. Clean up the code by packaging the complexity in `lambda` functions.

# %%
col_dict = { f"{col}_num" : X[col].map(likert_map).astype("Int64") for col in col_to_recode }
col_dict
# Out:
# {'F1_num': <dfply.base.Intention at 0x7fe3217269d0>,
#  'F1_1_num': <dfply.base.Intention at 0x7fe321726e20>,
#  'F1_2_num': <dfply.base.Intention at 0x7fe3215b0700>,
#  'F1_3_num': <dfply.base.Intention at 0x7fe3215b0b50>,
#  'F1_4_num': <dfply.base.Intention at 0x7fe3215b0fa0>,
#  'F1_5_num': <dfply.base.Intention at 0x7fe320e1a430>,
#  'F1_6_num': <dfply.base.Intention at 0x7fe320e1a880>,
#  'F1_7_num': <dfply.base.Intention at 0x7fe320e1acd0>,
#  'F2_num': <dfply.base.Intention at 0x7fe320dfe160>,
#  'F2_1_num': <dfply.base.Intention at 0x7fe320dfe5b0>,
#  'F2_10_num': <dfply.base.Intention at 0x7fe320dfea00>,
#  'F2_11_num': <dfply.base.Intention at 0x7fe320dfee50>,
#  'F2_2_num': <dfply.base.Intention at 0x7fe320e192e0>,
#  'F2_3_num': <dfply.base.Intention at 0x7fe320e19730>,
#  'F2_4_num': <dfply.base.Intention at 0x7fe320e19b80>,
#  'F2_5_num': <dfply.base.Intention at 0x7fe320e19fd0>,
#  'F2_6_num': <dfply.base.Intention at 0x7fe320e16460>,
#  'F2_7_num': <dfply.base.Intention at 0x7fe320e168b0>,
#  'F2_8_num': <dfply.base.Intention at 0x7fe320e16d00>,
#  'F2_9_num': <dfply.base.Intention at 0x7fe320e17190>,
#  'F3_num': <dfply.base.Intention at 0x7fe320e175e0>,
#  'F3_1_num': <dfply.base.Intention at 0x7fe320e17a30>,
#  'F3_2_num': <dfply.base.Intention at 0x7fe320e17e80>,
#  'F3_3_num': <dfply.base.Intention at 0x7fe320dff310>,
#  'F3_4_num': <dfply.base.Intention at 0x7fe320dff760>,
#  'F3_5_num': <dfply.base.Intention at 0x7fe320dffbb0>,
#  'F4_num': <dfply.base.Intention at 0x7fe320dfa040>,
#  'F4_1_num': <dfply.base.Intention at 0x7fe320dfa490>,
#  'F4_2_num': <dfply.base.Intention at 0x7fe320dfa8e0>,
#  'F4_3_num': <dfply.base.Intention at 0x7fe320dfad30>,
#  'F4_4_num': <dfply.base.Intention at 0x7fe320d9c1c0>,
#  'F5_num': <dfply.base.Intention at 0x7fe320d9c610>,
#  'F5_1_num': <dfply.base.Intention at 0x7fe320d9ca60>,
#  'F5_2_num': <dfply.base.Intention at 0x7fe320d9ceb0>,
#  'F5_3_num': <dfply.base.Intention at 0x7fe320d9d340>,
#  'F5_4_num': <dfply.base.Intention at 0x7fe320d9d790>,
#  'F5_5_num': <dfply.base.Intention at 0x7fe320d9dbe0>,
#  'F5_6_num': <dfply.base.Intention at 0x7fe320d9e070>,
#  'F5_7_num': <dfply.base.Intention at 0x7fe320d9e4c0>,
#  'F6_num': <dfply.base.Intention at 0x7fe320d9e910>,
#  'F6_1_num': <dfply.base.Intention at 0x7fe320d9ed60>,
#  'F6_2_num': <dfply.base.Intention at 0x7fe320da01f0>,
#  'F6_3_num': <dfply.base.Intention at 0x7fe3215a08b0>,
#  'F6_4_num': <dfply.base.Intention at 0x7fe320da0850>}

# %% [markdown]
# 5.  Use our dictionary in a mutate using `**` unpacking.

# %%
@make_symbolic
def to_likert_score(series):
    return X[series].map(likert_map).astype("Int64")

# %%
col_dict2 = { f"{col}_num" : to_likert_score(col) for col in col_to_recode}
col_dict2
# Out:
# {'F1_num': <dfply.base.Intention at 0x7fe321ab59d0>,
#  'F1_1_num': <dfply.base.Intention at 0x7fe321ab5c10>,
#  'F1_2_num': <dfply.base.Intention at 0x7fe321ab5850>,
#  'F1_3_num': <dfply.base.Intention at 0x7fe320db9070>,
#  'F1_4_num': <dfply.base.Intention at 0x7fe320db94c0>,
#  'F1_5_num': <dfply.base.Intention at 0x7fe320db9910>,
#  'F1_6_num': <dfply.base.Intention at 0x7fe320db9d60>,
#  'F1_7_num': <dfply.base.Intention at 0x7fe320dc21f0>,
#  'F2_num': <dfply.base.Intention at 0x7fe320dc2640>,
#  'F2_1_num': <dfply.base.Intention at 0x7fe320dc2a90>,
#  'F2_10_num': <dfply.base.Intention at 0x7fe320dc2ee0>,
#  'F2_11_num': <dfply.base.Intention at 0x7fe320dc4370>,
#  'F2_2_num': <dfply.base.Intention at 0x7fe320dc47c0>,
#  'F2_3_num': <dfply.base.Intention at 0x7fe320dc4c10>,
#  'F2_4_num': <dfply.base.Intention at 0x7fe320dc90a0>,
#  'F2_5_num': <dfply.base.Intention at 0x7fe320dc94f0>,
#  'F2_6_num': <dfply.base.Intention at 0x7fe320dc9940>,
#  'F2_7_num': <dfply.base.Intention at 0x7fe320dc9d90>,
#  'F2_8_num': <dfply.base.Intention at 0x7fe320dcb220>,
#  'F2_9_num': <dfply.base.Intention at 0x7fe320dcb670>,
#  'F3_num': <dfply.base.Intention at 0x7fe320dcbac0>,
#  'F3_1_num': <dfply.base.Intention at 0x7fe320dcbf10>,
#  'F3_2_num': <dfply.base.Intention at 0x7fe320dcc3a0>,
#  'F3_3_num': <dfply.base.Intention at 0x7fe320dcc7f0>,
#  'F3_4_num': <dfply.base.Intention at 0x7fe320dccc40>,
#  'F3_5_num': <dfply.base.Intention at 0x7fe320dce0d0>,
#  'F4_num': <dfply.base.Intention at 0x7fe320dce520>,
#  'F4_1_num': <dfply.base.Intention at 0x7fe320dce970>,
#  'F4_2_num': <dfply.base.Intention at 0x7fe320dcedc0>,
#  'F4_3_num': <dfply.base.Intention at 0x7fe320dd0250>,
#  'F4_4_num': <dfply.base.Intention at 0x7fe320dd06a0>,
#  'F5_num': <dfply.base.Intention at 0x7fe320dd0af0>,
#  'F5_1_num': <dfply.base.Intention at 0x7fe320dd0f40>,
#  'F5_2_num': <dfply.base.Intention at 0x7fe320dd13d0>,
#  'F5_3_num': <dfply.base.Intention at 0x7fe320dd1820>,
#  'F5_4_num': <dfply.base.Intention at 0x7fe320dd1ca0>,
#  'F5_5_num': <dfply.base.Intention at 0x7fe320dd31c0>,
#  'F5_6_num': <dfply.base.Intention at 0x7fe320dd36a0>,
#  'F5_7_num': <dfply.base.Intention at 0x7fe320dd3b80>,
#  'F6_num': <dfply.base.Intention at 0x7fe320dd40a0>,
#  'F6_1_num': <dfply.base.Intention at 0x7fe320dd4580>,
#  'F6_2_num': <dfply.base.Intention at 0x7fe320dd4a60>,
#  'F6_3_num': <dfply.base.Intention at 0x7fe320dd4f40>,
#  'F6_4_num': <dfply.base.Intention at 0x7fe320dd6460>}

# %%
(health_survey_fixed
    >> mutate(**col_dict2)
    >> head()
)
# Out:
#    ID              F1            F1_1            F1_2            F1_3  \
# 0   1  Somewhat Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 1   2  Somewhat Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 2   3  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 3   4  Somewhat Agree  Somewhat Agree  Strongly Agree  Somewhat Agree
# 4   5  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
#
#                          F1_4                        F1_5            F1_6  \
# 0  Neither Agree nor Disagree              Somewhat Agree  Somewhat Agree
# 1              Somewhat Agree  Neither Agree nor Disagree  Somewhat Agree
# 2           Somewhat Disagree              Strongly Agree  Strongly Agree
# 3  Neither Agree nor Disagree              Somewhat Agree  Strongly Agree
# 4              Somewhat Agree              Somewhat Agree  Strongly Agree
#
#                          F1_7                          F2            F2_1  \
# 0              Somewhat Agree              Somewhat Agree  Somewhat Agree
# 1              Somewhat Agree              Somewhat Agree  Somewhat Agree
# 2              Somewhat Agree              Somewhat Agree  Strongly Agree
# 3  Neither Agree nor Disagree              Strongly Agree  Strongly Agree
# 4              Somewhat Agree  Neither Agree nor Disagree  Somewhat Agree
#
#             F2_10           F2_11                        F2_2  \
# 0  Somewhat Agree  Somewhat Agree              Somewhat Agree
# 1  Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
# 2  Somewhat Agree  Somewhat Agree              Somewhat Agree
# 3  Somewhat Agree  Somewhat Agree              Strongly Agree
# 4  Somewhat Agree  Somewhat Agree              Somewhat Agree
#
#                 F2_3            F2_4            F2_5            F2_6  \
# 0     Somewhat Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 1     Somewhat Agree  Somewhat Agree  Somewhat Agree  Somewhat Agree
# 2     Somewhat Agree  Somewhat Agree  Strongly Agree  Somewhat Agree
# 3     Somewhat Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 4  Somewhat Disagree  Somewhat Agree  Strongly Agree  Strongly Agree
#
#              F2_7            F2_8            F2_9                          F3  \
# 0  Somewhat Agree  Somewhat Agree  Somewhat Agree              Somewhat Agree
# 1  Somewhat Agree  Somewhat Agree  Somewhat Agree  Neither Agree nor Disagree
# 2             NaN  Somewhat Agree  Somewhat Agree              Somewhat Agree
# 3  Somewhat Agree  Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 4  Somewhat Agree  Somewhat Agree  Somewhat Agree              Somewhat Agree
#
#                          F3_1                        F3_2  \
# 0           Somewhat Disagree              Somewhat Agree
# 1  Neither Agree nor Disagree  Neither Agree nor Disagree
# 2           Somewhat Disagree              Somewhat Agree
# 3           Somewhat Disagree           Somewhat Disagree
# 4              Somewhat Agree              Somewhat Agree
#
#                          F3_3               F3_4                        F3_5  \
# 0              Somewhat Agree  Somewhat Disagree              Somewhat Agree
# 1  Neither Agree nor Disagree     Somewhat Agree  Neither Agree nor Disagree
# 2              Somewhat Agree     Somewhat Agree           Strongly Disagree
# 3           Somewhat Disagree  Somewhat Disagree           Somewhat Disagree
# 4              Somewhat Agree     Somewhat Agree           Somewhat Disagree
#
#                            F4                        F4_1            F4_2  \
# 0              Somewhat Agree              Somewhat Agree  Somewhat Agree
# 1              Somewhat Agree  Neither Agree nor Disagree  Somewhat Agree
# 2              Somewhat Agree  Neither Agree nor Disagree  Somewhat Agree
# 3  Neither Agree nor Disagree  Neither Agree nor Disagree  Somewhat Agree
# 4              Strongly Agree  Neither Agree nor Disagree  Somewhat Agree
#
#                          F4_3                        F4_4  \
# 0  Neither Agree nor Disagree              Somewhat Agree
# 1  Neither Agree nor Disagree  Neither Agree nor Disagree
# 2  Neither Agree nor Disagree              Somewhat Agree
# 3              Somewhat Agree  Neither Agree nor Disagree
# 4  Neither Agree nor Disagree              Somewhat Agree
#
#                            F5                        F5_1               F5_2  \
# 0           Somewhat Disagree              Somewhat Agree     Somewhat Agree
# 1           Somewhat Disagree  Neither Agree nor Disagree     Somewhat Agree
# 2  Neither Agree nor Disagree              Somewhat Agree  Somewhat Disagree
# 3              Somewhat Agree              Somewhat Agree  Somewhat Disagree
# 4           Strongly Disagree  Neither Agree nor Disagree  Strongly Disagree
#
#              F5_3                        F5_4                        F5_5  \
# 0  Somewhat Agree              Somewhat Agree           Somewhat Disagree
# 1  Somewhat Agree  Neither Agree nor Disagree  Neither Agree nor Disagree
# 2  Somewhat Agree              Somewhat Agree           Somewhat Disagree
# 3  Somewhat Agree              Somewhat Agree           Somewhat Disagree
# 4  Strongly Agree  Neither Agree nor Disagree           Strongly Disagree
#
#                 F5_6            F5_7                          F6  \
# 0     Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 1  Somewhat Disagree  Somewhat Agree           Somewhat Disagree
# 2  Somewhat Disagree  Strongly Agree           Somewhat Disagree
# 3  Somewhat Disagree  Somewhat Agree  Neither Agree nor Disagree
# 4  Strongly Disagree  Strongly Agree           Strongly Disagree
#
#                          F6_1            F6_2                        F6_3  \
# 0              Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 1              Somewhat Agree  Somewhat Agree           Somewhat Disagree
# 2  Neither Agree nor Disagree  Somewhat Agree           Somewhat Disagree
# 3              Somewhat Agree  Somewhat Agree              Somewhat Agree
# 4              Somewhat Agree  Strongly Agree  Neither Agree nor Disagree
#
#                          F6_4  F1_num  F1_1_num  F1_2_num  F1_3_num  F1_4_num  \
# 0              Somewhat Agree       4         4         4         4         3
# 1           Somewhat Disagree       4         4         4         4         4
# 2              Somewhat Agree       5         5         5         5         2
# 3  Neither Agree nor Disagree       4         4         5         4         3
# 4              Somewhat Agree       5         5         5         5         4
#
#    F1_5_num  F1_6_num  F1_7_num  F2_num  F2_1_num  F2_10_num  F2_11_num  \
# 0         4         4         4       4         4          4          4
# 1         3         4         4       4         4          4          4
# 2         5         5         4       4         5          4          4
# 3         4         5         3       5         5          4          4
# 4         4         5         4       3         4          4          4
#
#    F2_2_num  F2_3_num  F2_4_num  F2_5_num  F2_6_num  F2_7_num  F2_8_num  \
# 0         4         4         4         4         4         4         4
# 1         3         4         4         4         4         4         4
# 2         4         4         4         5         4      <NA>         4
# 3         5         4         5         5         5         4         4
# 4         4         2         4         5         5         4         4
#
#    F2_9_num  F3_num  F3_1_num  F3_2_num  F3_3_num  F3_4_num  F3_5_num  F4_num  \
# 0         4       4         2         4         4         2         4       4
# 1         4       3         3         3         3         4         3       4
# 2         4       4         2         4         4         4         1       4
# 3         4       2         2         2         2         2         2       3
# 4         4       4         4         4         4         4         2       5
#
#    F4_1_num  F4_2_num  F4_3_num  F4_4_num  F5_num  F5_1_num  F5_2_num  \
# 0         4         4         3         4       2         4         4
# 1         3         4         3         3       2         3         4
# 2         3         4         3         4       3         4         2
# 3         3         4         4         3       4         4         2
# 4         3         4         3         4       1         3         1
#
#    F5_3_num  F5_4_num  F5_5_num  F5_6_num  F5_7_num  F6_num  F6_1_num  \
# 0         4         4         2         4         4       2         4
# 1         4         3         3         2         4       2         4
# 2         4         4         2         2         5       2         3
# 3         4         4         2         2         4       3         4
# 4         5         3         1         1         5       1         4
#
#    F6_2_num  F6_3_num  F6_4_num
# 0         4         2         4
# 1         4         2         2
# 2         4         2         4
# 3         4         4         3
# 4         5         3         4

# %% [markdown]
# #### Method 3 – Stack Transform Unstack.
#
# Another method for applying the
# same transformation to multiple columns is to (A) stack all the columns
# that need transformation, (B) applying the transformation to the stacked
# values column, and (C) unstacking the data back into the original shape.
# This is the approach you will apply in **Part 2**.

# %% [markdown]
# ## Part 2 – Performing data preparation
#
# Dr. Bergen, Director of the Statistical Consulting Center at WSU, needs
# you to prepare the attached data for analysis. The file
# **health_survey.csv** contains the responses to a series of
# health-related questions and we need to recode the responses as 1-5
# using the definition below. It is important to note that the clients
# consider “Strongly Agree” the best answer for most of the questions
# coded and want it mapped to 5, but there are a handful of questions for
# which they want the mapping reversed as “Strongly Disagree” the
# preferred answer. The two types of codings are illustrated in the table
# shown below and the list of questions that should receive the reverse
# coding are available in the file **ReverseCodingItems.csv**.
#
# | Old Label                    | Regular Coded Value | Reverse Coding |
# |------------------------------|---------------------|----------------|
# | “Strongly Disagree”          | 1                   | 5              |
# | “Somewhat Disagree”          | 2                   | 4              |
# | “Neither Agree nor Disagree” | 3                   | 3              |
# | “Somewhat Agree”             | 4                   | 2              |
# | “Strongly Agree”             | 5                   | 1              |
#
# **Note.** I have prototyped this process in JMP and have provided screenshots of the resulting tables as a guide.

# %% [markdown]
# 1.  Read in the `ReverseCodingItems.csv` file.  Note that the names in the `"Column Name"` column contain `"."`s.  Fix this, then look at the questions that need reverse coding and explain why it makes sense to reverse the coding on these items.

# %%
reverse_coding = (pd.read_csv('./data/ReverseCodingItems.csv')
                 >> mutate(Question = X['Column Name'].str.replace('.','_', regex = True))
                 )

reverse_coding.head()
# Out:
#   Question  Construct  Question # on Qualtrics Survey Needs Reverse Coding?  \
# 0       F1          1                               1                    No
# 1       F5          5                               2                   Yes
# 2       F2          2                               3                    No
# 3     F1_1          1                               4                    No
# 4     F2_1          2                               5                    No
#
#   Column Name
# 0          F1
# 1          F5
# 2          F2
# 3        F1.1
# 4        F2.1

# %% [markdown]
# <font color="blue"> *Your thoughts here* </font>

# %% [markdown]
# 2. Next, you will perform the data preparation by completing each of
#     the tasks listed below.  First, *Stack* the response columns.
#
# <img src="img/media/image1.png" style="width:2.91924in;height:1.85212in" alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.30.46%20" />
#
# Work in a pipe and add a temporary `head` at the end.

# %%
from more_dfply import *

# %%
(health_survey_fixed
 >> gather('Question', 'Response', columns_from('F1'))
 >> left_join(reverse_coding, by='Question')
>> drop('Construct','Question # on Qualtrics Survey','Column Name')
>> mutate(question_type = (X.Question.str.split('_').str.get(0)),
         coded_value = ifelse(X['Needs Reverse Coding?'] == 'Yes', X.Response.map(rev_coding),X.Response.map(likert_map))
                              .astype('Int64')
         )
 >> group_by(X.ID,X.question_type)
 >> summarise(total_coded_value = X.coded_value.sum())
 >> spread(X.question_type, X.total_coded_value)
 >> rename(Participant = 'ID')
)
# Out:
#      Participant  F1  F2  F3  F4  F5  F6
# 0              1  31  48  20  17  28  18
# 1              2  31  47  19  17  27  20
# 2              3  36  46  19  18  32  17
# 3              4  32  54  12  15  30  16
# 4              5  37  47  22  19  36  19
# ..           ...  ..  ..  ..  ..  ..  ..
# 259          260  32  50  22  18  34  22
# 260          261  31  48  24  19  28  15
# 261          262  30  47  20  23  33  19
# 262          263  38  50  20  19  31  21
# 263          264  33  53  16  21  33  17
#
# [264 rows x 7 columns]

# %%
likert_map #from above
# Out:
# {'Strongly Disagree': 1,
#  'Somewhat Disagree': 2,
#  'Neither Agree nor Disagree': 3,
#  'Somewhat Agree': 4,
#  'Strongly Agree': 5}

# %%
rev_coding = {resp:6 - score for resp, score in likert_map.items()}
rev_coding
# Out:
# {'Strongly Disagree': 5,
#  'Somewhat Disagree': 4,
#  'Neither Agree nor Disagree': 3,
#  'Somewhat Agree': 2,
#  'Strongly Agree': 1}

# %% [markdown]
# 3.  Make a new column called *Needs Reverse* by joining on
#     the `"Yes"` or `"No"` values from the *Needs Reverse Coding?* from **ReverseCodingItems.csv.**
#
# > <img src="img/media/image2.png"
# > style="width:3.78315in;"
# > alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.35.26%20" />
#
# Start by copying and adding to the pipe from the previous cell. In practice, you would continue to work in the same cell, but we are illustrating the standard best practice in working with data, by continually cycling through the following steps
#
# 1. Add the next step
# 2. Rerun your code to test.
#
# I want to verify that you are following this practice, which is why we will be copying our previous code to the next step

# %%
# Copy your last pipe and edit the code here

# %% [markdown]
# 4.   We already created a `dict` for the regular coding.  Make a `dict` for the reverse coding using a `dict` comprehension.  Remember to use the `items` method and two names to iterate through the original `dict`.  Use subtraction.

# %%
# Copy your last pipe and edit the code here

# %% [markdown]
# 5.   Next we need to make a column with the question type.  For example, all questions that start with `F1`, like `F1` and `F1_1`, need to be coded as `F1`.  Add a `mutate` to create this column using one of the string transformations (extract, split, etc.) from this module.
#
# > <img src="img/media/image6.png"
# > style="width:2.97769in;"
# > alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.45.03%20" />

# %%
# Copy your last pipe and edit the code here

# %% [markdown]
# 6.  Make a new column by *Recoding* the Question Types to *F1, F2, …,
#     F6.* based on the `Question Type`. **Hint:** You might want to use the `dfply.ifelse`.
#
# > <img src="img/media/image6.png"
# > style="width:2.97769in;"
# > alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.45.03%20" />

# %%
# Copy your last pipe and edit the code here

# %% [markdown]
# 7.  *Aggregate* and *unstack.*
#
# > <img src="img/media/image7.png"
# > style="width:2.46321in;"
# > alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.46.11%20" />
# > <img src="img/media/image8.png"
# > style="width:2.96893in;"
# > alt="../../../../Desktop/Screen%20Shot%202018-03-22%20at%201.46.34%20" />

# %%
# Copy your last pipe and edit the code here

# %% [markdown]
# 8.  Save the table to a csv file in the `data` folder.

# %%
# Your code here

# %% [markdown]
# **Deliverables.** Submit this document with your answer to question 1,
# the JMP file containing the results of Part 1, and a csv file with your
# final table.
