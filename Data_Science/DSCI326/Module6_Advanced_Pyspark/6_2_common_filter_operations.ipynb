# %% [markdown]
# # Advanced Filters
#
# In this section, we will take a closer look at common filtering patterns.  Note that this list is based on the Common Filter Operations section of the [SQL Alchemy tutorial](https://docs.sqlalchemy.org/en/latest/orm/tutorial.html) from the SQL Alchemy documentation, which is copyright © by SQLAlchemy authors and contributors. SQLAlchemy and its documentation are licensed under the MIT license.

# %% [markdown]
# ### Common Filter Operators
#
# Most filters consist of the following patterns.
#
# * EQUALS/NOT EQUALS and other inequalities
# * LIKE and ILIKE
# * IN and NOT IN
# * IS NULL and IS NOT NULL
# * AND and OR
# * CONTAINS
# * `text_filter` and `text_facet`

# %% [markdown]
# ## How we will proceed
#
# Let's look at how each of the operations is performed in `pyspark`.  We need a dataset that is ripe for filtering, so we will return to the super hero data set.  Who doesn't love a super hero?

# %% [markdown]
# ## Set up

# %%
from pyspark.sql import SparkSession
from more_pyspark import to_pandas

spark = SparkSession.builder.appName('Ops').getOrCreate()
# Out:
# 22/10/31 23:27:36 WARN Utils: Your hostname, nn1448lr222 resolves to a loopback address: 127.0.1.1; using 172.22.172.170 instead (on interface eth0)
# 22/10/31 23:27:36 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/31 23:27:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/10/31 23:27:39 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/10/31 23:27:39 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
heros = (spark.read.csv('./data/heroes_information.csv', 
                       header=True, 
                       inferSchema=True,
                       nanValue='-99.0',
                       nullValue='-')
        )

heros.take(2) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %%
from more_pyspark import pprint_schema

heros >> pprint_schema
# Out:
# StructType([StructField('ID', IntegerType(), True),
#             StructField('name', StringType(), True),
#             StructField('Gender', StringType(), True),
#             StructField('Eye color', StringType(), True),
#             StructField('Race', StringType(), True),
#             StructField('Hair color', StringType(), True),
#             StructField('Height', DoubleType(), True),
#             StructField('Publisher', StringType(), True),
#             StructField('Skin color', StringType(), True),
#             StructField('Alignment', StringType(), True),
#             StructField('Weight', DoubleType(), True)])

# %% [markdown]
# ## Category 1 - Equality and Inequality
#
# In `pyspark`, equalities/inequalities are performed using the regular Python operators on column expressions.

# %% [markdown]
# #### EQUALS

# %%
from pyspark.sql.functions import col

(heros
 .where(col('Eye color') == 'blue')
 .take(2)
) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 1   2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics       blue      good    65.0
# 1          DC Comics        red      good    90.0

# %% [markdown]
# #### not equals:

# %%
(heros
 .where(col('Eye color') != 'blue')
 .take(2)) >> to_pandas
# Out:
#    ID         name Gender Eye color               Race Hair color  Height  \
# 0   0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   3  Abomination   Male     green  Human / Radiation    No Hair   203.0
#
#        Publisher Skin color Alignment  Weight
# 0  Marvel Comics       None      good   441.0
# 1  Marvel Comics       None       bad   441.0

# %% [markdown]
# #### Other inequalities

# %%
(heros
 .where(heros.Height > 200)
 .where(heros.Weight <= 440)
 .take(2)
) >> to_pandas
# Out:
#    ID   name Gender Eye color             Race Hair color  Height  \
# 0  17  Alien   Male      None  Xenomorph XX121    No Hair   244.0
# 1  19  Amazo   Male       red          Android       None   257.0
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics      black       bad   169.0
# 1          DC Comics       None       bad   173.0

# %% [markdown]
# ## LIKE and ILIKE
#
# `LIKE` and `ILIKE` are a SQL idiom that
#
# * is used to match string patterns
# * Uses the `%` wildcard
#     * like `*` in a regular expression
# * `LIKE` is case-sensitive
# * `ILIKE` is case-insensitive
#     * Actual details are platform dependent

# %% [markdown]
# ### Examples
#
# * `abc%` matches any string that starts with `abc`
# * `%abc` matches any string that ends with `abc`
# * `%abc%` matches any string that contains `abc`

# %% [markdown]
# ## `pyspark` columns have a case-sensitive `like` method

# %%
(heros
 .where(heros.name.like('%boy%'))
 .take(2)) >> to_pandas
# Out:
#     ID       name Gender Eye color   Race Hair color  Height  \
# 0  142  Bumbleboy   Male      None   None       None     NaN
# 1  321    Hellboy   Male      gold  Demon      Black   259.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good     NaN
# 1  Dark Horse Comics       None      good   158.0

# %% [markdown]
# ## Replicating `ILIKE` in `pyspark`
#
# * No `ilike` method
# * Use `lower` then `like`

# %%
from pyspark.sql.functions import lower

(heros
 .where(lower(heros.name).like('%boy%'))
 .take(2)) >> to_pandas
# Out:
#    ID       name Gender Eye color   Race Hair color  Height  Publisher  \
# 0  46  Astro Boy   Male     brown   None      Black     NaN       None
# 1  75  Beast Boy   Male     green  Human      Green   173.0  DC Comics
#
#   Skin color Alignment  Weight
# 0       None      good     NaN
# 1      green      good    68.0

# %% [markdown]
# ## Unleash the power of `rlike`
#
# `rlike` is `like` with RegEx

# %%
from pyspark.sql.functions import lower
(heros
 .where(heros.name.rlike('\s[bB]oy|\wboy'))
 .where(heros.Publisher.rlike('DC Comics|Marvel'))
 .take(2)) >> to_pandas
# Out:
#     ID       name Gender Eye color   Race Hair color  Height      Publisher  \
# 0   75  Beast Boy   Male     green  Human      Green   173.0      DC Comics
# 1  142  Bumbleboy   Male      None   None       None     NaN  Marvel Comics
#
#   Skin color Alignment  Weight
# 0      green      good    68.0
# 1       None      good     NaN

# %% [markdown]
# ## Checking membership with `IN` and `NOT IN`
#
# `SQL` has `IN` and `NOT IN`, which are used to check if a value is in/not in a collection.  In `pyspark`, this action is performed using the column expression `isin` method and negating the expression for performing `NOT IN`.

# %% [markdown]
# #### `IN` in `pyspark`

# %%
(heros
 .where(heros.Publisher.isin(['DC Comics', 'Marvel Comics']))
 .take(2)) >> to_pandas
# Out:
#    ID      name Gender Eye color     Race Hair color  Height      Publisher  \
# 0   0    A-Bomb   Male    yellow    Human    No Hair   203.0  Marvel Comics
# 1   2  Abin Sur   Male      blue  Ungaran    No Hair   185.0      DC Comics
#
#   Skin color Alignment  Weight
# 0       None      good   441.0
# 1        red      good    90.0

# %% [markdown]
# #### `NOT IN` in `pyspark`

# %%
(heros
 .where(~heros.Publisher.isin(['DC Comics', 'Marvel Comics']))
 .take(2)) >> to_pandas
# Out:
#    ID         name Gender Eye color           Race Hair color  Height  \
# 0   1   Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 1   6  Adam Monroe   Male      blue           None      Blond     NaN
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics       blue      good    65.0
# 1       NBC - Heroes       None      good     NaN

# %% [markdown]
# ## Using  `IS NULL`/`IS NOT NULL` in `pyspark`
#
# * `pyspark` uses the column `isnull` method for text columns
# * `pyspark` uses the column `isnan` method for numeric columns
# * Prepend column expression with `~` for `NOT IN`

# %% [markdown]
# #### `IS  NULL` in `pyspark`
#
# Check for `Null` in text columns

# %%
(heros
 .where(col('Skin color').isNull())
 .collect()) >> to_pandas
# Out:
#       ID             name  Gender Eye color               Race  \
# 0      0           A-Bomb    Male    yellow              Human
# 1      3      Abomination    Male     green  Human / Radiation
# 2      4          Abraxas    Male      blue      Cosmic Entity
# 3      5    Absorbing Man    Male      blue              Human
# 4      6      Adam Monroe    Male      blue               None
# ..   ...              ...     ...       ...                ...
# 657  727      Yellow Claw    Male      blue               None
# 658  728     Yellowjacket    Male      blue              Human
# 659  729  Yellowjacket II  Female      blue              Human
# 660  732          Zatanna  Female      blue              Human
# 661  733             Zoom    Male       red               None
#
#            Hair color  Height      Publisher Skin color Alignment  Weight
# 0             No Hair   203.0  Marvel Comics       None      good   441.0
# 1             No Hair   203.0  Marvel Comics       None       bad   441.0
# 2               Black     NaN  Marvel Comics       None       bad     NaN
# 3             No Hair   193.0  Marvel Comics       None       bad   122.0
# 4               Blond     NaN   NBC - Heroes       None      good     NaN
# ..                ...     ...            ...        ...       ...     ...
# 657           No Hair   188.0  Marvel Comics       None       bad    95.0
# 658             Blond   183.0  Marvel Comics       None      good    83.0
# 659  Strawberry Blond   165.0  Marvel Comics       None      good    52.0
# 660             Black   170.0      DC Comics       None      good    57.0
# 661             Brown   185.0      DC Comics       None       bad    81.0
#
# [662 rows x 11 columns]

# %% [markdown]
# #### `IS  NULL` in `pyspark`
#
# Check for `nan` in numeric columns

# %%
from pyspark.sql.functions import isnan

(heros
 .where(isnan(heros.Weight))
 .take(2)
) >> to_pandas
# Out:
#    ID         name Gender Eye color           Race Hair color  Height  \
# 0   4      Abraxas   Male      blue  Cosmic Entity      Black     NaN
# 1   6  Adam Monroe   Male      blue           None      Blond     NaN
#
#        Publisher Skin color Alignment  Weight
# 0  Marvel Comics       None       bad     NaN
# 1   NBC - Heroes       None      good     NaN

# %% [markdown]
# #### Use `~` to perform `IS  NOT NULL` in `pyspark`
#
# As above, we have to look for both `Null` (text column) and `NaN` (numeric column)

# %%
(heros
 .where(~col('Skin color').isNull())
 .take(2)) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 1   2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics       blue      good    65.0
# 1          DC Comics        red      good    90.0

# %%
(heros
 .where(~isnan(heros.Weight))
 .take(2)) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %% [markdown]
# ## `AND` and `OR`

# %% [markdown]
# #### `AND` using `&`

# %%
(heros
 .where((col('Hair color') == 'No Hair') & (col('Eye color') == 'blue'))
 .take(2)) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 1   2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics       blue      good    65.0
# 1          DC Comics        red      good    90.0

# %% [markdown]
# #### `AND` using multiple `where`s

# %%
(heros
 .where(col('Hair color') == 'No Hair')
 .where(col('Eye color') == 'blue')
 .take(2)) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 1   2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0  Dark Horse Comics       blue      good    65.0
# 1          DC Comics        red      good    90.0

# %% [markdown]
# #### `OR` using `|`

# %%
(heros
 .where((col('Hair color') == 'No Hair') | (col('Eye color') == 'blue'))
 .take(2)) >> to_pandas
# Out:
#    ID        name Gender Eye color           Race Hair color  Height  \
# 0   0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1   1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %% [markdown]
# ## CONTAINS using the column `contains` method
#
# * CONTAINS is used to look for substrings
# * `pyspark` column expressions have `contains` method
# * Similar to LIKE and RLIKE but no wild-cards
# * Doesn't accept regular expressions
#     * Use `rlike` in those cases

# %%
(heros
.where(heros.Publisher.contains('Comics'))
.where(col('name').contains('-'))
.take(5)
) >> to_pandas
# Out:
#    ID          name Gender Eye color           Race Hair color  Height  \
# 0   0        A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  11    Air-Walker   Male      blue           None      White   188.0
# 2  29       Ant-Man   Male      blue          Human      Blond   211.0
# 3  30    Ant-Man II   Male      blue          Human      Blond   183.0
# 4  31  Anti-Monitor   Male    yellow  God / Eternal    No Hair    61.0
#
#        Publisher Skin color Alignment  Weight
# 0  Marvel Comics       None      good   441.0
# 1  Marvel Comics       None       bad   108.0
# 2  Marvel Comics       None      good   122.0
# 3  Marvel Comics       None      good    86.0
# 4      DC Comics       None       bad     NaN

# %% [markdown]
# ## Refactoring conditional statements
#
#
# * Column expression are lazy, which makes refactoring easy.
# * Make code readable by refactoring all conditional expressions.

# %% [markdown]
# ### Example - The Super Hero Dating Game - Part 1
#
# Yesterday, you notice another singles add in the local paper, which reads
#
# > SBiM looking for SyFy super hero (will also consider Star Wars, Star Trek, or NBC - Heroes).  Eye color must be either blue or brown and last name must start with either B or P.
#
# 1. Write a query in `pyspark` to help find candidates for this personal add.
# 2. Refactor the conditional expressions to be more readable.

# %%
# Original solution
(heros
 .select(heros.name,
         'Eye color',
         heros.Publisher)
 .where(heros.Publisher.isin(['NBC - Heroes', 'SyFy', 'Star Trek', 'George Lucas']))
 .where(col('Eye color').rlike('blue|brown'))
 .where(heros.name.rlike(' [BP]'))
 .collect()
) >> to_pandas
# Out:
#               name Eye color     Publisher
# 0    Claire Bennet      blue  NBC - Heroes
# 1      Elle Bishop      blue  NBC - Heroes
# 2  Nathan Petrelli     brown  NBC - Heroes

# %%
# refactored solution

is_syfy = heros.Publisher.isin(['NBC - Heroes', 'SyFy', 'Star Trek', 'George Lucas'])
has_blue_or_brown_eyes = col('Eye color').rlike('blue|brown')
name_startswith_B_or_P = heros.name.rlike(' [BP]')

(heros
 .select(heros.name,
         'Eye color',
         heros.Publisher)
 .where(is_syfy & has_blue_or_brown_eyes & name_startswith_B_or_P)
 .collect()
) >> to_pandas
# Out:
#               name Eye color     Publisher
# 0    Claire Bennet      blue  NBC - Heroes
# 1      Elle Bishop      blue  NBC - Heroes
# 2  Nathan Petrelli     brown  NBC - Heroes

# %% [markdown]
# ## <font color="red"> Exercise 6.2.3 - The Super Hero Dating Game - Part 3</font>
#
# Yesterday, you notice one more singles add in the local paper, which read
#
# > W4A (Woman for Androgynous) looking for super hero.  Must be tall (at least 6 feet tall) and either God/Eternal/Cosmic Entity; or have no body hair.  Bad heroes need not reply.
#
# 1. Write a query in all three frameworks to help find candidates for this personal add.  You should complete each query with **exactly one filter_by/where**.
# 2. Refactor all conditional statements.

# %%
# Your dfply solution here
import pandas as pd
from dfply import *

taller_than_6 = (X.Height >= 6)
has_no_hair = (X['Hair color'] == 'No Hair')
is_eternal = (X.Race.isin(['God','Eternal','Cosmic Entity']))
is_not_bad = (X.Alignment != 'bad')

heroespd = pd.read_csv('./data/heroes_information.csv')
(heroespd
 >> mutate(Height = X.Height / 30.48)
 >> filter_by( taller_than_6 &
              (has_no_hair | is_eternal) &
              is_not_bad
             )
)
# Out:
#       ID                name  Gender Eye color               Race Hair color  \
# 0      0              A-Bomb    Male    yellow              Human    No Hair
# 1      1          Abe Sapien    Male      blue      Icthyo Sapien    No Hair
# 2      2            Abin Sur    Male      blue            Ungaran    No Hair
# 78    78       Beta Ray Bill    Male         -                  -    No Hair
# 91    91              Bishop    Male     brown             Mutant    No Hair
# 102  102     Black Lightning    Male     brown                  -    No Hair
# 212  212            Deadpool    Male     brown             Mutant    No Hair
# 233  233  Drax the Destroyer    Male       red    Human / Altered    No Hair
# 245  245             Etrigan    Male       red              Demon    No Hair
# 255  255       Fin Fang Foom    Male       red    Kakarantharaian    No Hair
# 272  272            Galactus    Male     black      Cosmic Entity      Black
# 279  279         Ghost Rider    Male       red              Demon    No Hair
# 337  337            Hyperion    Male      blue            Eternal        Red
# 377  377               K-2SO    Male     white            Android    No Hair
# 388  388             Kilowog    Male       red         Bolovaxian    No Hair
# 428  428           Man-Thing    Male       red                  -    No Hair
# 432  432   Martian Manhunter    Male       red            Martian    No Hair
# 446  446          Metamorpho    Male     black                  -    No Hair
# 528  528         Professor X    Male      blue             Mutant    No Hair
# 553  553         Red Tornado    Male     green            Android    No Hair
# 592  592           She-Thing  Female      blue  Human / Radiation    No Hair
# 600  600       Silver Surfer    Male     white              Alien    No Hair
# 637  637               Steel    Male     brown                  -    No Hair
# 660  660               Thing    Male      blue  Human / Radiation    No Hair
# 679  679              Triton    Male     green            Inhuman    No Hair
# 699  699              Vision    Male      gold            Android    No Hair
# 700  700           Vision II       -       red                  -    No Hair
# 730  730                Ymir    Male     white        Frost Giant    No Hair
#
#         Height          Publisher Skin color Alignment  Weight
# 0     6.660105      Marvel Comics          -      good   441.0
# 1     6.266404  Dark Horse Comics       blue      good    65.0
# 2     6.069554          DC Comics        red      good    90.0
# 78    6.594488      Marvel Comics          -      good   216.0
# 91    6.496063      Marvel Comics          -      good   124.0
# 102   6.069554          DC Comics          -      good    90.0
# 212   6.167979      Marvel Comics          -   neutral    95.0
# 233   6.332021      Marvel Comics      green      good   306.0
# 245   6.332021          DC Comics     yellow   neutral   203.0
# 255  31.988189      Marvel Comics      green      good    18.0
# 272  28.740157      Marvel Comics          -   neutral    16.0
# 279   6.167979      Marvel Comics          -      good    99.0
# 337   6.003937      Marvel Comics          -      good   207.0
# 377   6.988189       George Lucas       gray      good   -99.0
# 388   7.677165          DC Comics       pink      good   324.0
# 428   6.988189      Marvel Comics      green      good   225.0
# 432   6.594488          DC Comics      green      good   135.0
# 446   6.069554          DC Comics          -      good    90.0
# 528   6.003937      Marvel Comics          -      good    86.0
# 553   6.069554          DC Comics          -      good   146.0
# 592   6.003937      Marvel Comics          -      good   153.0
# 600   6.332021      Marvel Comics     silver      good   101.0
# 637   6.594488          DC Comics          -      good   131.0
# 660   6.003937      Marvel Comics          -      good   225.0
# 679   6.167979      Marvel Comics      green      good    86.0
# 699   6.266404      Marvel Comics        red      good   135.0
# 700   6.266404      Marvel Comics          -      good   135.0
# 730  10.000000      Marvel Comics      white      good   -99.0

# %%
# Your pyspark solution here
from pyspark.sql.functions import column, col

taller_than_6 = (heros.Height >= 6)
has_no_hair = (col('Hair color') == 'No Hair')
is_eternal = (heros.Race.isin(['God','Eternal','Cosmic Entity']))
is_not_bad = (heros.Alignment != 'bad')

(heros
 .withColumn('Height', heros.Height/30.48)
 .where(taller_than_6 & (has_no_hair | is_eternal) & is_not_bad)
 .collect()
) >> to_pandas
# Out:
#      ID                name  Gender Eye color               Race Hair color  \
# 0     0              A-Bomb    Male    yellow              Human    No Hair
# 1     1          Abe Sapien    Male      blue      Icthyo Sapien    No Hair
# 2     2            Abin Sur    Male      blue            Ungaran    No Hair
# 3    78       Beta Ray Bill    Male      None               None    No Hair
# 4    91              Bishop    Male     brown             Mutant    No Hair
# 5   102     Black Lightning    Male     brown               None    No Hair
# 6   112         Blaquesmith    None     black               None    No Hair
# 7   120           Bloodhawk    Male     black             Mutant    No Hair
# 8   189      Crimson Dynamo    Male     brown               None    No Hair
# 9   212            Deadpool    Male     brown             Mutant    No Hair
# 10  227           Donatello    Male     green             Mutant    No Hair
# 11  232        Dr Manhattan    Male     white     Human / Cosmic    No Hair
# 12  233  Drax the Destroyer    Male       red    Human / Altered    No Hair
# 13  245             Etrigan    Male       red              Demon    No Hair
# 14  255       Fin Fang Foom    Male       red    Kakarantharaian    No Hair
# 15  272            Galactus    Male     black      Cosmic Entity      Black
# 16  279         Ghost Rider    Male       red              Demon    No Hair
# 17  337            Hyperion    Male      blue            Eternal        Red
# 18  342                 Ink    Male      blue             Mutant    No Hair
# 19  377               K-2SO    Male     white            Android    No Hair
# 20  388             Kilowog    Male       red         Bolovaxian    No Hair
# 21  393        Kool-Aid Man    Male     black               None    No Hair
# 22  404            Leonardo    Male      blue             Mutant    No Hair
# 23  410     Living Tribunal    None      blue      Cosmic Entity    No Hair
# 24  428           Man-Thing    Male       red               None    No Hair
# 25  432   Martian Manhunter    Male       red            Martian    No Hair
# 26  446          Metamorpho    Male     black               None    No Hair
# 27  473               Morph    Male     white               None    No Hair
# 28  502       One Punch Man    Male      None              Human    No Hair
# 29  503       One-Above-All    None      None      Cosmic Entity       None
# 30  528         Professor X    Male      blue             Mutant    No Hair
# 31  543             Raphael    Male      None             Mutant    No Hair
# 32  553         Red Tornado    Male     green            Android    No Hair
# 33  592           She-Thing  Female      blue  Human / Radiation    No Hair
# 34  600       Silver Surfer    Male     white              Alien    No Hair
# 35  610               Sobek    Male     white               None    No Hair
# 36  615             Spectre    Male     white      God / Eternal    No Hair
# 37  637               Steel    Male     brown               None    No Hair
# 38  660               Thing    Male      blue  Human / Radiation    No Hair
# 39  679              Triton    Male     green            Inhuman    No Hair
# 40  699              Vision    Male      gold            Android    No Hair
# 41  700           Vision II    None       red               None    No Hair
# 42  730                Ymir    Male     white        Frost Giant    No Hair
#
#        Height          Publisher Skin color Alignment  Weight
# 0    6.660105      Marvel Comics       None      good   441.0
# 1    6.266404  Dark Horse Comics       blue      good    65.0
# 2    6.069554          DC Comics        red      good    90.0
# 3    6.594488      Marvel Comics       None      good   216.0
# 4    6.496063      Marvel Comics       None      good   124.0
# 5    6.069554          DC Comics       None      good    90.0
# 6         NaN      Marvel Comics       None      good     NaN
# 7         NaN      Marvel Comics       None      good     NaN
# 8    5.905512      Marvel Comics       None      good   104.0
# 9    6.167979      Marvel Comics       None   neutral    95.0
# 10        NaN     IDW Publishing      green      good     NaN
# 11        NaN          DC Comics       blue      good     NaN
# 12   6.332021      Marvel Comics      green      good   306.0
# 13   6.332021          DC Comics     yellow   neutral   203.0
# 14  31.988189      Marvel Comics      green      good    18.0
# 15  28.740157      Marvel Comics       None   neutral    16.0
# 16   6.167979      Marvel Comics       None      good    99.0
# 17   6.003937      Marvel Comics       None      good   207.0
# 18   5.905512      Marvel Comics       None      good    81.0
# 19   6.988189       George Lucas       gray      good     NaN
# 20   7.677165          DC Comics       pink      good   324.0
# 21        NaN               None        red      good     NaN
# 22        NaN     IDW Publishing      green      good     NaN
# 23        NaN      Marvel Comics       gold   neutral     NaN
# 24   6.988189      Marvel Comics      green      good   225.0
# 25   6.594488          DC Comics      green      good   135.0
# 26   6.069554          DC Comics       None      good    90.0
# 27   5.839895      Marvel Comics       None      good    79.0
# 28   5.741470           Shueisha       None      good    69.0
# 29        NaN      Marvel Comics       None   neutral     NaN
# 30   6.003937      Marvel Comics       None      good    86.0
# 31        NaN     IDW Publishing      green      good     NaN
# 32   6.069554          DC Comics       None      good   146.0
# 33   6.003937      Marvel Comics       None      good   153.0
# 34   6.332021      Marvel Comics     silver      good   101.0
# 35        NaN          DC Comics       None      good     NaN
# 36        NaN          DC Comics      white      good     NaN
# 37   6.594488          DC Comics       None      good   131.0
# 38   6.003937      Marvel Comics       None      good   225.0
# 39   6.167979      Marvel Comics      green      good    86.0
# 40   6.266404      Marvel Comics        red      good   135.0
# 41   6.266404      Marvel Comics       None      good   135.0
# 42  10.000000      Marvel Comics      white      good     NaN

# %%
# Your sqlalchemy solution here
