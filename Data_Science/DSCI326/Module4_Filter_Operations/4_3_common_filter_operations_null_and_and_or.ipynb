# %% [markdown]
# ### Common Filter Operators
#
# Next, we look at the final topics on our list of filters, namely
#
# * Is Null/is not null
# * And/or

# %%
import pandas as pd
from dfply import *
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Set up
#
# Let's read in a data set

# %%
from more_dfply import fix_names
heroes_raw = pd.read_csv('./data/heroes_information.csv', na_values=['-', '-99.0', '', 'None'])
heroes = (heroes_raw >> fix_names)
heroes.head()
# Out:
#    Unnamed_0         name Gender Eye_color               Race Hair_color  \
# 0          0       A-Bomb   Male    yellow              Human    No Hair
# 1          1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2          2     Abin Sur   Male      blue            Ungaran    No Hair
# 3          3  Abomination   Male     green  Human / Radiation    No Hair
# 4          4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin_color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics        NaN       bad   441.0
# 4     NaN      Marvel Comics        NaN       bad     NaN

# %% [markdown]
# ## Checking for `IS NULL` and `IS NOT NULL`
#
# `SQL` has `IS NULL` and `IS NOT NULL`, which are used to check for missing values.

# %% [markdown]
# ## Using  `IS NULL`/`IS NOT NULL` in `pandas +dfply`
#
# `pandas` and `pyspark` use the column `isnull`/`isNull` method

# %% [markdown]
# #### `IS NULL`

# %%
(heroes
 >> filter_by(X.Skin_color.isnull())
 >> head(2))
# Out:
#    Unnamed_0         name Gender Eye_color               Race Hair_color  \
# 0          0       A-Bomb   Male    yellow              Human    No Hair
# 3          3  Abomination   Male     green  Human / Radiation    No Hair
#
#    Height      Publisher Skin_color Alignment  Weight
# 0   203.0  Marvel Comics        NaN      good   441.0
# 3   203.0  Marvel Comics        NaN       bad   441.0

# %% [markdown]
# #### `IS NOT NULL`

# %%
(heroes
 >> filter_by(~X.Skin_color.isnull())
 >> head(2))
# Out:
#    Unnamed_0        name Gender Eye_color           Race Hair_color  Height  \
# 1          1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 2          2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin_color Alignment  Weight
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0

# %% [markdown]
# ## Combining expressions with `AND` and `OR`
#
# `SQL` has `AND` and `OR`, which are used to check for missing values.

# %% [markdown]
# ### Using  `AND`/`OR` in  `pandas`
#
#  `pandas` uses `&` and `|` to combine column expressions.

# %%
(heroes
 >> filter_by((X.Hair_color == 'No Hair') & (X.Eye_color == 'blue'))
 >> head(2))
# Out:
#    Unnamed_0        name Gender Eye_color           Race Hair_color  Height  \
# 1          1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 2          2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin_color Alignment  Weight
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0

# %%
(heroes
 >> filter_by((X.Hair_color == 'No Hair') | (X.Eye_color == 'blue'))
 >> head(2))
# Out:
#    Unnamed_0        name Gender Eye_color           Race Hair_color  Height  \
# 0          0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1          1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin_color Alignment  Weight
# 0      Marvel Comics        NaN      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %% [markdown]
# #### Important NOTE
# You need to break the Python habit of using `and` and `or` (hard to do)

# %%
(heroes
 >> filter_by((X.Hair_color == 'No Hair') and (X.Eye_color == 'blue'))
 >> head(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       1 (heroes
# ----> 2  >> filter_by((X.Hair_color == 'No Hair') and (X.Eye_color == 'blue'))
#       3  >> head(2))
#
# TypeError: __index__ returned non-int (type Intention)

# %% [markdown]
# ## <font color="red"> Exercise 4.3.1 - The Super Hero Dating Game - Part 3</font>
#
# Yesterday, you notice one more singles add in the local paper, which read
#
# > W4A (Woman for Androgynous) looking for super hero.  Must be either God/Eternal/Cosmic Entity; or have no body hair.  Bad heroes need not reply.
#
# Write a query in all three frameworks to help find candidates for this personal add.  You should complete each query with **exactly one filter_by/where**.

# %%
# Your dfply solution here
(heroes
 >> filter_by( ((X.Race.str.contains('God|Eternal|Cosmic Entity',na=False)) | (X.Hair_color == 'No Hair'))
               & (X.Alignment == 'good'))
)
# Out:
#      Unnamed_0                name  Gender Eye_color               Race  \
# 0            0              A-Bomb    Male    yellow              Human
# 1            1          Abe Sapien    Male      blue      Icthyo Sapien
# 2            2            Abin Sur    Male      blue            Ungaran
# 78          78       Beta Ray Bill    Male       NaN                NaN
# 79          79            Beyonder    Male       NaN      God / Eternal
# 90          90             Birdman    Male       NaN      God / Eternal
# 91          91              Bishop    Male     brown             Mutant
# 102        102     Black Lightning    Male     brown                NaN
# 112        112         Blaquesmith     NaN     black                NaN
# 120        120           Bloodhawk    Male     black             Mutant
# 159        159      Captain Planet    Male       red      God / Eternal
# 160        160    Captain Universe     NaN       NaN      God / Eternal
# 189        189      Crimson Dynamo    Male     brown                NaN
# 227        227           Donatello    Male     green             Mutant
# 232        232        Dr Manhattan    Male     white     Human / Cosmic
# 233        233  Drax the Destroyer    Male       red    Human / Altered
# 255        255       Fin Fang Foom    Male       red    Kakarantharaian
# 279        279         Ghost Rider    Male       red              Demon
# 324        324            Hercules    Male      blue           Demi-God
# 337        337            Hyperion    Male      blue            Eternal
# 342        342                 Ink    Male      blue             Mutant
# 377        377               K-2SO    Male     white            Android
# 388        388             Kilowog    Male       red         Bolovaxian
# 393        393        Kool-Aid Man    Male     black                NaN
# 404        404            Leonardo    Male      blue             Mutant
# 428        428           Man-Thing    Male       red                NaN
# 432        432   Martian Manhunter    Male       red            Martian
# 446        446          Metamorpho    Male     black                NaN
# 473        473               Morph    Male     white                NaN
# 498        498                Odin    Male      blue      God / Eternal
# 502        502       One Punch Man    Male       NaN              Human
# 528        528         Professor X    Male      blue             Mutant
# 543        543             Raphael    Male       NaN             Mutant
# 553        553         Red Tornado    Male     green            Android
# 592        592           She-Thing  Female      blue  Human / Radiation
# 600        600       Silver Surfer    Male     white              Alien
# 610        610               Sobek    Male     white                NaN
# 615        615             Spectre    Male     white      God / Eternal
# 637        637               Steel    Male     brown                NaN
# 660        660               Thing    Male      blue  Human / Radiation
# 679        679              Triton    Male     green            Inhuman
# 699        699              Vision    Male      gold            Android
# 700        700           Vision II     NaN       red                NaN
