# %%
# !pip install more_itertools
# Out:
# Collecting more_itertools
#   Downloading more_itertools-8.14.0-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 609 kB/s eta 0:00:011
# Installing collected packages: more-itertools
# Successfully installed more-itertools-8.14.0

# %%
# !pip install more_dfply
# Out:
# Requirement already satisfied: more_dfply in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (0.2.10)
# Requirement already satisfied: composable<0.3.0,>=0.2.5 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from more_dfply) (0.2.5)
# Requirement already satisfied: dfply<0.4.0,>=0.3.3 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from more_dfply) (0.3.3)
# Requirement already satisfied: toolz<0.12.0,>=0.11.1 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from composable<0.3.0,>=0.2.5->more_dfply) (0.11.2)
# Requirement already satisfied: python-forge<19.0,>=18.6 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from composable<0.3.0,>=0.2.5->more_dfply) (18.6.0)
# Requirement already satisfied: pandas in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dfply<0.4.0,>=0.3.3->more_dfply) (1.4.2)
# Requirement already satisfied: numpy in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dfply<0.4.0,>=0.3.3->more_dfply) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pandas->dfply<0.4.0,>=0.3.3->more_dfply) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pandas->dfply<0.4.0,>=0.3.3->more_dfply) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/wavessurfer/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->dfply<0.4.0,>=0.3.3->more_dfply) (1.16.0)

# %% [markdown]
# ## OpenRefine-like Filters and Facets
#
# [OpenRefine](https://openrefine.org) is a great tool for inspecting and cleaning data, in no small part due to a workflow that makes heavy use of filters and facets.  In this lecture, we will develop/discuss tools for replicating these filters and facets in `Python` and `more_dfply`

# %%
import pandas as pd
from dfply import *

# %%
artists = pd.read_csv("./data/Artists.csv")

# %% [markdown]
# ### Text filter
#
# <img src="./img/text_filter.png"/>
#
# First, we will create a function to mimic the text filter.  This function will need to
#
# 1. Accept column intention in the first argument.
# 2. Accept text in the second argument
# 3. Allow for the following optional arguments: `case=False`, `invert=False`, `regex=False`

# %% [markdown]
# #### Performing a text filter

# %%
from more_dfply.facets import text_filter

(artists
 >> filter_by(text_filter(X.Nationality, 'american'))
 >> head
)
# Out:
#    ConstituentID      DisplayName                      ArtistBio Nationality  \
# 0              1   Robert Arneson            American, 1930–1992    American
# 2              3      Bill Arnold            American, born 1941    American
# 3              4  Charles Arnoldi            American, born 1946    American
# 6              7        Bill Aron            American, born 1941    American
# 7              9    David Aronson  American, born Lithuania 1923    American
#
#   Gender  BeginDate  EndDate  Wiki QID         ULAN
# 0   Male       1930     1992       NaN          NaN
# 2   Male       1941        0       NaN          NaN
# 3   Male       1946        0  Q1063584  500027998.0
# 6   Male       1941        0       NaN          NaN
# 7   Male       1923        0  Q5230870  500003363.0

# %% [markdown]
# #### Inverting the search with `~`

# %%
(artists
 >> filter_by(~text_filter(X.Nationality, 'american'))
 >> head
)
# Out:
#     ConstituentID      DisplayName                                 ArtistBio  \
# 1               2   Doroteo Arnaiz                        Spanish, born 1936
# 4               5      Per Arnoldi                         Danish, born 1941
# 5               6    Danilo Aroldi                        Italian, born 1925
# 9              11  Jean (Hans) Arp  French, born Germany (Alsace). 1886–1966
# 10             12       Jüri Arrak                       Estonian, born 1936
#
#    Nationality Gender  BeginDate  EndDate Wiki QID         ULAN
# 1      Spanish   Male       1936        0      NaN          NaN
# 4       Danish   Male       1941        0      NaN          NaN
# 5      Italian   Male       1925        0      NaN          NaN
# 9       French   Male       1886     1966  Q153739  500031000.0
# 10    Estonian   Male       1936        0      NaN          NaN

# %% [markdown]
# #### Switching to a case sensitive search

# %%
(artists
 >> filter_by(text_filter(X.Nationality, 'amer', case=True))
 >> head
)
# Out:
#        ConstituentID       DisplayName               ArtistBio  Nationality  \
# 12313          38243  Barthelemy Toguo  Cameroonian, born 1967  Cameroonian
#
#       Gender  BeginDate  EndDate Wiki QID  ULAN
# 12313   Male       1967        0      NaN   NaN

# %% [markdown]
# #### Using a regular expression

# %%
(artists
 >> filter_by(text_filter(X.ArtistBio, ', born \d{4}', regex=True))
 >> head
)
# Out:
#    ConstituentID      DisplayName            ArtistBio Nationality Gender  \
# 1              2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2              3      Bill Arnold  American, born 1941    American   Male
# 3              4  Charles Arnoldi  American, born 1946    American   Male
# 4              5      Per Arnoldi    Danish, born 1941      Danish   Male
# 5              6    Danilo Aroldi   Italian, born 1925     Italian   Male
#
#    BeginDate  EndDate  Wiki QID         ULAN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN
# 5       1925        0       NaN          NaN

# %%
(artists
 >> filter_by(X.ArtistBio.str.contains(', born \d{4}', regex=True, na=False))
 >> head
)
# Out:
#    ConstituentID      DisplayName            ArtistBio Nationality Gender  \
# 1              2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2              3      Bill Arnold  American, born 1941    American   Male
# 3              4  Charles Arnoldi  American, born 1946    American   Male
# 4              5      Per Arnoldi    Danish, born 1941      Danish   Male
# 5              6    Danilo Aroldi   Italian, born 1925     Italian   Male
#
#    BeginDate  EndDate  Wiki QID         ULAN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN
# 5       1925        0       NaN          NaN

# %% [markdown]
# #### You can combine `text_filter`s with `&` and `|`

# %%
(artists
 >> filter_by((text_filter(X.ArtistBio, ', born \d{4}', regex=True) 
               & text_filter(X.Nationality, 'American')))
 >> head
)
# Out:
#     ConstituentID      DisplayName            ArtistBio Nationality Gender  \
# 2               3      Bill Arnold  American, born 1941    American   Male
# 3               4  Charles Arnoldi  American, born 1946    American   Male
# 6               7        Bill Aron  American, born 1941    American   Male
# 19             24  Donald Ashcraft  American, born 1927    American   Male
# 38             44      Robert Abel  American, born 1937    American   Male
#
#     BeginDate  EndDate  Wiki QID         ULAN
# 2        1941        0       NaN          NaN
# 3        1946        0  Q1063584  500027998.0
# 6        1941        0       NaN          NaN
# 19       1927        0       NaN          NaN
# 38       1937        0  Q7341326          NaN

# %% [markdown]
# ## Inspecting and filtering with `text_facet`s
#
# <img src="./img/text_facet.png"/>
#
# Text facets are another powerful OpenRefine tool, which allow you to
#
# 1. Inspect all the unique labels in a column along with their frequencies
# 2. Filter rows by including/excluding various labels
# 3. Perform transformation on the filtered rows.

# %% [markdown]
# #### Inspecting text facets with `get_text_facet`

# %%
from more_dfply.facets import get_text_facets
from composable.sequence import slice

(get_text_facets(artists.Nationality) 
 #>> slice(0,5) # Like head but for lists
)
# Out:
# [('American', 5194),
#  ('German', 969),
#  ('British', 854),
#  ('French', 848),
#  ('Italian', 539),
#  ('Japanese', 509),
#  ('Swiss', 294),
#  ('Dutch', 277),
#  ('Russian', 267),
#  ('Austrian', 242),
#  ('Canadian', 193),
#  ('Nationality unknown', 180),
#  ('Brazilian', 163),
#  ('Spanish', 160),
#  ('Argentine', 140),
#  ('Polish', 130),
#  ('Swedish', 130),
#  ('Mexican', 129),
#  ('Danish', 119),
#  ('Belgian', 93),
#  ('Chinese', 80),
#  ('Czech', 78),
#  ('Israeli', 74),
#  ('Chilean', 72),
#  ('South African', 68),
#  ('Cuban', 63),
#  ('Finnish', 61),
#  ('Venezuelan', 60),
#  ('Australian', 55),
#  ('Colombian', 54),
#  ('Hungarian', 53),
#  ('Norwegian', 47),
#  ('Indian', 38),
#  ('Peruvian', 37),
#  ('Korean', 34),
#  ('Croatian', 27),
#  ('Uruguayan', 24),
#  ('Yugoslav', 23),
#  ('Turkish', 22),
#  ('Irish', 22),
#  ('Scottish', 20),
#  ('Romanian', 20),
#  ('New Zealander', 17),
#  ('Haitian', 16),
#  ('Portuguese', 13),
#  ('Greek', 12),
#  ('Icelandic', 12),
#  ('Iranian', 11),
#  ('Ukrainian', 11),
#  ('Serbian', 11),
#  ('Slovenian', 9),
#  ('Slovak', 8),
#  ('Bosnian', 8),
#  ('Egyptian', 8),
#  ('Guatemalan', 7),
#  ('Lebanese', 7),
#  ('Czechoslovakian', 6),
#  ('Congolese', 6),
#  ('Georgian', 5),
#  ('Taiwanese', 5),
#  ('Zimbabwean', 5),
#  ('Bulgarian', 5),
#  ('Moroccan', 5),
#  ('Algerian', 5),
#  ('Puerto Rican', 5),
#  ('Macedonian', 5),
#  ('Palestinian', 5),
#  ('Vietnamese', 5),
#  ('Nigerian', 4),
#  ('Ecuadorian', 4),
#  ('Native American', 4),
#  ('Pakistani', 4),
#  ('Albanian', 3),
#  ('Malaysian', 3),
#  ('Filipino', 3),
#  ('Lithuanian', 3),
#  ('Canadian Inuit', 3),
#  ('Thai', 3),
#  ('Luxembourgish', 3),
#  ('Estonian', 3),
#  ('Bolivian', 3),
#  ('Costa Rican', 2),
#  ('Welsh', 2),
#  ('Kyrgyzstani', 2),
#  ('Panamanian', 2),
#  ('Senegalese', 2),
#  ('Namibian', 2),
#  ('Singaporean', 2),
#  ('Paraguayan', 2),
#  ('Ghanaian', 2),
#  ('Latvian', 2),
#  ('Nicaraguan', 2),
#  ('Malian', 2),
#  ('Emirati', 2),
#  ('Kenyan', 2),
#  ('Ethiopian', 2),
#  ('Tunisian', 2),
#  ('Bangladeshi', 1),
#  ('Bahamian', 1),
#  ('Sahrawi', 1),
#  ('Azerbaijani', 1),
#  ('Coptic', 1),
#  ('Catalan', 1),
#  ('Burkinabe', 1),
#  ('Beninese', 1),
#  ('Sierra Leonean', 1),
#  ('Persian', 1),
#  ('Cameroonian', 1),
#  ('Kuwaiti', 1),
#  ('Ivorian', 1),
#  ('Ugandan', 1),
#  ('Sudanese', 1),
#  ('Guyanese', 1),
#  ('Afghan', 1),
#  ('Cambodian', 1),
#  ('Tanzanian', 1),
#  ('Cypriot', 1),
#  ('Salvadoran', 1)]

# %% [markdown]
# #### Filtering rows using `text_facet`

# %%
from more_dfply.facets import text_facet

(artists
 >> filter_by(text_facet(X.Nationality, 'American','Canadian','Mexican'))
 >> head(10)
)
# Out:
#     ConstituentID          DisplayName                      ArtistBio  \
# 0               1       Robert Arneson            American, 1930–1992
# 2               3          Bill Arnold            American, born 1941
# 3               4      Charles Arnoldi            American, born 1946
# 6               7            Bill Aron            American, born 1941
# 7               9        David Aronson  American, born Lithuania 1923
# 8              10        Irene Aronson    American, born Germany 1918
# 11             13  J. Arrelano Fischer             Mexican, 1911–1995
# 15             19  Richard Artschwager            American, 1923–2013
# 16             21           Ruth Asawa            American, 1926–2013
# 19             24      Donald Ashcraft            American, born 1927
#
#    Nationality  Gender  BeginDate  EndDate   Wiki QID         ULAN
# 0     American    Male       1930     1992        NaN          NaN
# 2     American    Male       1941        0        NaN          NaN
# 3     American    Male       1946        0   Q1063584  500027998.0
# 6     American    Male       1941        0        NaN          NaN
# 7     American    Male       1923        0   Q5230870  500003363.0
# 8     American  Female       1918        0  Q19748568  500042413.0
# 11     Mexican    Male       1911     1995        NaN          NaN
# 15    American    Male       1923     2013    Q568262  500114981.0
# 16    American  Female       1926     2013   Q7382874  500077806.0
# 19    American    Male       1927        0        NaN          NaN

# %% [markdown]
# #### `text_facet` takes any combination of strings and lists of strings as arguments

# %%
(artists
 >> filter_by(text_facet(X.Nationality, 'American',['Canadian','Mexican']))
 >> head(10)
)
# Out:
#     ConstituentID          DisplayName                      ArtistBio  \
# 0               1       Robert Arneson            American, 1930–1992
# 2               3          Bill Arnold            American, born 1941
# 3               4      Charles Arnoldi            American, born 1946
# 6               7            Bill Aron            American, born 1941
# 7               9        David Aronson  American, born Lithuania 1923
# 8              10        Irene Aronson    American, born Germany 1918
# 11             13  J. Arrelano Fischer             Mexican, 1911–1995
# 15             19  Richard Artschwager            American, 1923–2013
# 16             21           Ruth Asawa            American, 1926–2013
# 19             24      Donald Ashcraft            American, born 1927
#
#    Nationality  Gender  BeginDate  EndDate   Wiki QID         ULAN
# 0     American    Male       1930     1992        NaN          NaN
# 2     American    Male       1941        0        NaN          NaN
# 3     American    Male       1946        0   Q1063584  500027998.0
# 6     American    Male       1941        0        NaN          NaN
# 7     American    Male       1923        0   Q5230870  500003363.0
# 8     American  Female       1918        0  Q19748568  500042413.0
# 11     Mexican    Male       1911     1995        NaN          NaN
# 15    American    Male       1923     2013    Q568262  500114981.0
# 16    American  Female       1926     2013   Q7382874  500077806.0
# 19    American    Male       1927        0        NaN          NaN

# %% [markdown]
# ## <font color="red"> Exercise 4.4.1 - The Super Hero Dating Game - Part 3</font>
#
# Let's redo Exercise 4.2.1, but this time using our new tools.  Here is the prompt for that previous exercise.
#
# > Yesterday, you notice another singles add in the local paper, which reads
#
# >> SBiM looking for SyFy super hero (will also consider Star Wars (George Lucas), Star Trek, or NBC - Heroes ... check the `Publisher` column).  Eye color must be either blue or brown and last name must start with either B or P.
#
# Rewrite the query using `text_filter` and `text_facet`.

# %%
from more_dfply import fix_names
from dfply import *
heroes_raw = pd.read_csv('./data/heroes_information.csv', na_values=['-', '-99.0', ''])
heroes = (heroes_raw >> fix_names)
heroes.head()
# Out:
#    Unnamed_0         name Gender Eye_color               Race Hair_color  \
# 0          0       A-Bomb   Male    yellow              Human    No Hair
# 1          1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2          2     Abin Sur   Male      blue            Ungaran    No Hair
# 3          3  Abomination   Male     green  Human / Radiation    No Hair
# 4          4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin_color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics        NaN       bad   441.0
# 4     NaN      Marvel Comics        NaN       bad     NaN

# %%
# Your code here
(heroes
 >> filter_by(text_facet(X.Publisher, 'George Lucas','Star Trek','NBC - Heroes'),
              text_filter(X.Eye_color, 'blue|brown', regex=True),
              text_filter(X.name, '\sB|P', regex=True, case=True)
             )
)
# Out:
#      Unnamed_0             name  Gender Eye_color Race Hair_color  Height  \
# 177        177    Claire Bennet  Female      blue  NaN      Blond     NaN
# 238        238      Elle Bishop  Female      blue  NaN      Blond     NaN
# 486        486  Nathan Petrelli    Male     brown  NaN        NaN     NaN
#
#         Publisher Skin_color Alignment  Weight
# 177  NBC - Heroes        NaN      good     NaN
# 238  NBC - Heroes        NaN       bad     NaN
# 486  NBC - Heroes        NaN      good     NaN
